# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import kagglehub as kh
import pandas as pd

# %%
path = kh.dataset_download("andrewsundberg/college-basketball-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: /home/teaganabritten/.cache/kagglehub/datasets/andrewsundberg/college-basketball-dataset/versions/10

# %%
df = pd.read_csv("/home/teaganabritten/.cache/kagglehub/datasets/andrewsundberg/college-basketball-dataset/versions/10/cbb.csv")
df.head(10)
# Out:
#              TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0  North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1       Wisconsin  B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2        Michigan  B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3      Texas Tech  B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4         Gonzaga  WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
# 5        Kentucky  SEC  40  29  117.2   96.2   0.9062   49.9   46.0  18.1
# 6        Michigan  B10  38  30  121.5   93.7   0.9522   54.6   48.0  14.6
# 7            Duke  ACC  39  35  125.2   90.6   0.9764   56.6   46.5  16.3
# 8        Virginia  ACC  38  35  123.0   89.9   0.9736   55.2   44.7  14.7
# 9  North Carolina  ACC  39  33  121.0   91.5   0.9615   51.7   48.1  16.2
#
#    ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 0  ...  30.4  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016
# ...

# %%
import matplotlib.pyplot as plt

df['SEED'] = pd.to_numeric(df['SEED'])

df2 = df[df['SEED'] < 5]

sns.scatterplot(df2, x = 'ADJOE', y = 'ADJDE', hue = 'CONF')
# Out:
# <Axes: xlabel='ADJOE', ylabel='ADJDE'>

# %%
sns.scatterplot(df, x ='W', y = 'BARTHAG', hue = 'CONF')
p5 = ['ACC', 'BE', 'B12', 'B10', 'SEC']

# %%
# Out:
#                       TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  \
# 0           North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1
# 1                Wisconsin  B10  40  36  129.1   93.6   0.9758   54.8   47.7
# 2                 Michigan  B10  40  33  114.4   90.4   0.9375   53.9   47.7
# 3               Texas Tech  B12  38  31  115.2   85.2   0.9696   53.5   43.0
# 4                  Gonzaga  WCC  39  37  117.8   86.3   0.9728   56.6   41.1
# ...                    ...  ...  ..  ..    ...    ...      ...    ...    ...
# 1989       Houston Baptist  GWC  27  11   85.7  102.4   0.1137   43.8   47.3
# 2012                  NJIT  GWC  25  12   93.0  102.0   0.2569   45.8   45.1
# 2015  UT Rio Grande Valley  GWC  28  12   90.5  106.3   0.1346   47.4   49.5
# 3232              Hartford  ind  25   5   89.5  117.5   0.0418   47.7   55.4
# 3288           Chicago St.  ind  27  11  101.3  113.1   0.2198   48.8   53.3
#
# ...

# %%
filtered_df = df[df['CONF'].isin(p5)]

# Save the filtered DataFrame to a new CSV file
filtered_df.to_csv('/home/teaganabritten/.cache/kagglehub/datasets/andrewsundberg/college-basketball-dataset/versions/10/cbbp5.csv', index=False)

# %%
import os
print(os.getcwd())
# Out:
# /mnt/c/Users/teaga/AppData/Local/Programs/Microsoft VS Code

# %%
df2y = df[(df['YEAR'] == 2024) | (df['YEAR'] == 2013)]

df2y.head()

df2y.to_csv('/home/teaganabritten/.cache/kagglehub/datasets/andrewsundberg/college-basketball-dataset/versions/10/cbb2y.csv', index=False)

# %%
import numpy as np
filtered_df['ADJ_T'] = (filtered_df['ADJ_T'] - np.mean(filtered_df['ADJ_T'], axis = 0)) / np.std(filtered_df['ADJ_T'], axis = 0)
filtered_df['BARTHAG'] = (filtered_df['BARTHAG'] - np.mean(filtered_df['BARTHAG'], axis = 0)) / np.std(filtered_df['BARTHAG'], axis = 0)

filtered_df.head()
filtered_df.to_csv('/home/teaganabritten/.cache/kagglehub/datasets/andrewsundberg/college-basketball-dataset/versions/10/cbbp52.csv', index=False)
# Out:
# /tmp/ipykernel_385772/207532778.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_385772/207532778.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
np.min(df['WAB'])
np.max(df['WAB'])
# Out:
# np.float64(13.1)

# %%
sns.scatterplot(filtered_df, x = 'WAB', y = 'BARTHAG', hue = 'POSTSEASON', palette = 'viridis')
plt.xlabel('Wins Against Bubble')
plt.ylabel('Power Rating')
# Out:
# Text(0, 0.5, 'Power Rating')
